# %% [markdown]
# # 1.하드웨어와 메모리 개념 정리

# %% [markdown]
# Python에서 변수를 배우기 전에, 먼저 컴퓨터가 데이터를 어떻게 저장하고 처리하는지 이해하는 것이 중요합니다. 변수는 단순한 개념이 아니라, 실제로는 메모리라는 공간에 데이터를 저장하고 이름을 붙이는 것이기 때문입니다.

# %% [markdown]
# ### 1. 주요 구성 요소
#
# <img src='./images/하드웨어.png' width='500'>

# %% [markdown]
# - CPU (중앙처리장치)
# - 메모리 (RAM)
# - 저장장치 (SSD/HDD)
# - 입력장치 (키보드, 마우스)
# - 출력장치 (모니터) 등

# %% [markdown]
# ### 2.CPU의 역할
# CPU는 계산하고 판단하는 역할을 합니다.
#
# - 연산 수행 (덧셈, 비교 등)
# - 프로그램 명령 실행
# - 전체 시스템 제어

# %% [markdown]
# vs. GPU (병렬 연산 처리)
# - 단일 성능은 CPU 만큼 속도가 빠르진 않음
# - AI 는 행렬 연산
# - CPU 를 도와서 연산을 빠르게 처리하기 위해 필요하다

# %% [markdown]
# ### 3. 메모리(RAM)의 역할
# 메모리는 현재 실행 중인 데이터를 저장하는 공간입니다.
#
# - 프로그램 실행 시 필요한 데이터 저장
# - 변수 값이 저장되는 곳
# - 빠른 읽기/쓰기 가능

# %% [markdown]
# # 2. Python 파일의 실행
# Python 코드는 단순한 텍스트 파일(.py)이지만, 실행되는 순간에는 CPU와 메모리를 통해 실제 프로그램으로 동작합니다.

# %% [markdown]
# ### 1. 시작 상태 (파일 저장)
#
# ```
# # test.py
# print("Hello, Python")
# ```
# - 👉 이 파일은 현재 저장장치(SSD/HDD) 에 저장되어 있는 상태입니다.
# - 👉 아직 실행된 것이 아니라 단순한 텍스트입니다.

# %% [markdown]
# ### 2. 실행 명령 입력
#
# ```
# python test.py
# ```
# 👉 이 명령은 “Python 프로그램을 실행해라” 라는 의미입니다.

# %% [markdown]
# ### 3.Python 인터프리터 실행
#
# 👉 Python 인터프리터(실행 프로그램)가 먼저 실행됩니다.
# >Python은 컴파일 언어가 아니라 인터프리터 언어입니다. 코드를 한 줄씩 읽고 실행합니다.

# %% [markdown]
# > vs 컴파일 언어 : 프로그래머가 작성한 소스 코드 전체를 컴파일러(Compiler)를 통해 기계어(0과 1)로 한 번에 변환하여 실행 파일을 만드는 언어

# %% [markdown]
# ### 4. 메모리(RAM)에 코드 로드
#
# - 👉 .py 파일이 저장장치 → 메모리(RAM)로 올라옵니다.
# - 👉 CPU는 저장장치가 아니라 메모리에서만 작업 가능

# %% [markdown]
# ### 5. CPU가 코드 실행
#
# - 👉 CPU가 메모리에 있는 코드를 읽어서 실행합니다.
# - 👉 CPU → RAM에서 코드 읽기 → 실행
#
# CPU는 내부적으로 아래와 같이 처리합니다.
# ```
# # test.py
# print("Hello, Python")
#
# '''
# 1. print 함수 찾기
# 2. "Hello, Python" 문자열 확인
# 3. 출력 명령 실행
# '''
# ```
#
# >👉 CPU → 출력 시스템 → 화면(모니터)
