# %% [markdown]
# # 1. input 함수
# input 함수는 사용자로부터 키보드 입력을 받는 데 사용되는 내장 함수이다. 프로그램 실행중에 사용자가 값을 입력하면, 입력한 값이 문자열로 반환되어 변수에 저장하거나 처리할 수 있다.

# %%
input() # 입력한 값을 저장하거나 변수에 할당하지 않음 / input() 함수가 찍어주는 건 아님. 파이썬 자체에서 찍어주는 기능이 있음.
# Out:
# '김사과'

# %%
a = 10
b = 5
a
# Out:
# 10

# %%
name = input()
name
# Out:
# '김사과'

# %%
a = "10"
b = "5"
# 10 + 5
print(a + " + " + b + " = " + (str(int(a) + int(b)))) # 문자열로 입력받은 a와 b를 정수로 변환하여 더한 후, 다시 문자열로 변환하여 출력
print(f"{a} + {b} = {(str(int(a) + int(b)))}") # f-string을 사용하여 더 간결하게 표현
# Out:
# 10 + 5 = 15
# 10 + 5 = 15

# %%
name = input('이름을 입력하세요') # input() 함수는 문자열로 입력을 받음
print(f'{name}님 안녕하세요!')
# Out:
# 김사과님 안녕하세요!

# %%
# name = '김사과'
# age = 20
# weight = 50.5
name, age, weight = '김사과', 20, 50.5

# %%
name, age, weight = input('이름, 나이, 몸무게를 입력하세요').split(' ')
# input() 함수로 입력받은 문자열을 쉼표로 구분하여 리스트로 반환한 후, 각각의 값을 name, age, weight 변수에 할당
print(name)
print(age)
print(weight)
# Out:
# 김사과
# 20
# 50.5

# %%
num1 = input('첫 번째 숫자를 입력하세요') # input() 함수로 입력받은 문자열로 저장한다.
num2 = input('두 번째 숫자를 입력하세요')
print('결과: ', num1 + num2)
# Out:
# 결과:  105

# %%
# int() : 문자열을 숫자 (정수) 타입으로 변환
num1 = input('첫 번째 숫자를 입력하세요') # input() 함수로 입력받은 문자열로 저장한다.
num2 = input('두 번째 숫자를 입력하세요')
print('결과: ', int(num1) + int(num2)) # 문자열로 저장된 num1과 num2를 정수로 변환하여 더한 후, 결과를 출력
# Out:
# 결과:  15

# %% [markdown]
# # 2. print 함수
# print 함수는 콘솔에 출력을 표시하는 가장 기본적인 함수이다. 프로그램 실행 중 생성된 값을 사용자(개발자)에게 보여주거나 디버깅할 때 매우 유용하다

# %%
print('안녕하세요 파이썬')
print("안녕하세요 파이썬")
print(10)
print('10')
print(10, 20, 30, 40)
print('안녕하세요', '파이썬')
# Out:
# 안녕하세요 파이썬
# 안녕하세요 파이썬
# 10
# 10
# 10 20 30 40
# 안녕하세요 파이썬

# %%
print(10, 20, 30, 40, sep='😎')
print(10, 20, 30, 40, sep=' ')

print('Hello', end='') # end 매개변수는 print() 함수가 출력한 후에 어떤 문자를 출력할지를 지정하는 매개변수
print('Python')
print('Hello')
print('Hello', end=' ')
print('Python')
print('Hello', end='🎁')
print('Python')
# Out:
# 10😎20😎30😎40
# 10 20 30 40
# HelloPython
# Hello
# Hello Python
# Hello🎁Python

# %% [markdown]
# # 3. 이스케이프 문자
# 파이썬에서 이스케이프 문자(Escape Character)는 특별한 의미를 가지며, 문자열 내에서 특수한 기능을 수행하도록 하는 문자이다. 이스케이프 문자는 백슬래스(\\)로 시작하며, 그 뒤에 이어지는 문자가 특정한 기능을 수행합니다.
#
# 1. \n: 줄바꿈을 나타냅니다.
# 2. \t: 탭 문자를 나타냅니다.
# 3. \\: 백슬래시 자체를 나타냅니다.
# 4. \" 또는 \': 큰따옴표나 작은따옴표를 나타냅니다. 문자열을 감싸는 따옴표와 구분하기 위해 사용됩니다.
# 5. \r: 캐리지 리턴을 나타냅니다. 문자열을 출력한 후 커서를 줄의 처음으로 이동시킵니다.
# 6. \b: 백스페이스를 나타냅니다. 문자열 내에서 한 글자를 삭제합니다.

# %%
print("Hello\nPython!")
print("Hello", end="\n")
print("Python!")

print("Name:\t김사과")
print("한국 원화: \\")
print("C:\\Users\\Administrator\\Documents")
# Out:
# Hello
# Python!
# Hello
# Python!
# Name:	김사과
# 한국 원화: \
# C:\Users\Administrator\Documents

# %% [markdown]
# # 4. 출력서식 지정
# 파이썬의 print() 함수에서 서식 지정(formating)은 변수를 문자열 내에 삽입하거나, 숫자의 출력 형식을 지정하는 방법이다.
#
# ### 1. % 서식 지정자
# - %s: 문자열
# - %d: 정수
# - %f: 실수
# - %x: 16진수

# %%
num = 255
pi = 3.141592
name = "김사과"

# 데이터 타입에 따른 출력 형식 지정 (데이터 타입이 안맞으면 오류 발생)
print("문자열 출력: %s" % name)        # %s
print("정수 출력: %d" % num)           # %d
print("실수 출력: %f" % pi)            # %f
print("소수점 자리 지정: %.2f" % pi)   # %.mf
print("16진수 출력: %x" % num)         # %x
print("0 채움 정수: %05d" % 42)        # %0n
print("여러 값 출력: %s %d %.2f" % (name, num, pi))  # 여러 값 tuple로 전달
# Out:
# 문자열 출력: 김사과
# 정수 출력: 255
# 실수 출력: 3.141592
# 소수점 자리 지정: 3.14
# 16진수 출력: ff
# 0 채움 정수: 00042
# 여러 값 출력: 김사과 255 3.14

# %% [markdown]
# ### 2. str.format() 메서드
#
# - {}: 중괄호 안에 변수나 표현식을 넣어 값을 출력합니다.
# - {:d}: 정수를 출력합니다.
# - {:f}: 부동 소수점 숫자를 출력합니다.
# - {:s}: 문자열을 출력합니다.
# - {:x}: 정수를 16진수로 출력합니다.
# - {:0n}: n 자리의 정수를 0으로 채워서 출력합니다.
# - {:n.mf}: 전체 길이 n과 소수점 이하 자리수 m을 지정하여 부동 소수점 숫자를 출력합니다.

# %%
num = 255
pi = 3.141592
name = "김사과"

print("기본 출력: {}".format(name))                # {}
print("정수 출력: {:d}".format(num))               # {:d}
print("실수 출력: {:f}".format(pi))                # {:f}
print("문자열 출력: {:s}".format(name))            # {:s}
print("16진수 출력: {:x}".format(num))            # {:x}
print("0 채움 정수: {:05d}".format(42))           # {:0n}
print("소수점 자리 지정: {:.2f}".format(pi))        # {:.mf}
print("전체 길이 + 소수점: {:10.2f}".format(pi))    # {:n.mf}
# Out:
# 기본 출력: 김사과
# 정수 출력: 255
# 실수 출력: 3.141592
# 문자열 출력: 김사과
# 16진수 출력: ff
# 0 채움 정수: 00042
# 소수점 자리 지정: 3.14
# 전체 길이 + 소수점:       3.14

# %%
print("기본 출력: {}".format(name))                # {}
print(f"기본 출력: {name}")                        # f-string
print("기본 출력: " + name)                        # 문자열 연결 연산자
# Out:
# 기본 출력: 김사과
# 기본 출력: 김사과
# 기본 출력: 김사과

# %% [markdown]
# ### 3. f-string
# f-string은 가장 직관적이고 간편한 방식이다. 문자열 앞에 f를 붙이고 중괄호 {} 안에 변수를 넣어 사용한다

# %%
name = "김사과"
age = 20

print(f"이름은 {name}이고 나이는 {age}입니다.")
# Out:
# 이름은 김사과이고 나이는 20입니다.

# %%
a = 10
b = 20
pi = 3.14159

print(f"{a} + {b} = {a + b}")
print(f"{pi}를 소수 둘째자리까지 표현 {pi:.2f}")
# Out:
# 10 + 20 = 30
# 3.14159를 소수 둘째자리까지 표현 3.14
